# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")

file_path = "./data/loan_data_set.csv"
data = pd.read_csv(file_path)
df  = pd.DataFrame(data)

# %% [markdown]
# A) Bar Plot – Plot the number of male/female applicants.

# %%
data = df['Gender']
sns.barplot(df, x=data.value_counts().index, y=data.value_counts().values, hue=data.value_counts().values).set_title('Number of Applicants Vs Gender')
# Out:
# Text(0.5, 1.0, 'Number of Applicants Vs Gender')

# %% [markdown]
# B) Strip Plot – Plot this with respect to the Applicant Income by grouping according to their Property area.

# %%
sns.stripplot(df, x=df['ApplicantIncome'], y=df['Property_Area'], hue=df['Property_Area']).set_title('Applicant Income Vs Property Area')
# Out:
# Text(0.5, 1.0, 'Applicant Income Vs Property Area')
